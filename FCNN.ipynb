# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Out:
# 2025-03-07 11:09:34.711418: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741363774.732478 3420465 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741363774.739072 3420465 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-07 11:09:34.761383: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("Loading training data...")

#load training dataset
training_data = pd.read_csv("Training_data_uhi_index_2025-02-18.csv")

#convert datetime column to usable format
training_data["datetime"] = pd.to_datetime(training_data["datetime"], format="%d-%m-%Y %H:%M")

training_data["hour"] = training_data["datetime"].dt.hour
training_data["month"] = training_data["datetime"].dt.month
training_data["day_of_week"] = training_data["datetime"].dt.dayofweek

training_data.drop(columns=["datetime", "Longitude", "Latitude"], inplace=True)

features = ["hour", "month", "day_of_week"]
X_train = training_data[features].values
y_train = training_data["UHI Index"].values 

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

y_scaler = MinMaxScaler()
y_train = y_scaler.fit_transform(y_train.reshape(-1, 1)).flatten()

print("Training data processed successfully.")

print("Loading validation data...")

validation_data = pd.read_csv("Submission_template.csv")

validation_data["hour"] = np.linspace(0, 23, len(validation_data), dtype=int) % 24
validation_data["month"] = np.linspace(1, 12, len(validation_data), dtype=int) % 12 + 1
validation_data["day_of_week"] = np.linspace(0, 6, len(validation_data), dtype=int) % 7

validation_data.drop(columns=["Longitude", "Latitude"], inplace=True)

X_val = scaler.transform(validation_data[features])


model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.1), 
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.1),
    Dense(16, activation='relu'),
    BatchNormalization(),
    Dropout(0.05),
    Dense(1, activation='sigmoid') 
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

history = model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=32, verbose=1)

print("Model training complete.")


y_train_pred = model.predict(X_train)

mae = mean_absolute_error(y_train, y_train_pred)
mse = mean_squared_error(y_train, y_train_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_train, y_train_pred)

#evaluation results
print("### Model Evaluation on Training Data ###")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R² Score: {r2:.4f}")

# ========== STEP 5: MAKE PREDICTIONS ON VALIDATION DATA ==========
print("Making predictions on validation dataset...")

#predict UHI Index on validation set
uhi_predictions = model.predict(X_val)

#transform predictions back to original UHI Index scale
uhi_predictions = y_scaler.inverse_transform(uhi_predictions.reshape(-1, 1)).flatten()

validation_data["UHI Index"] = uhi_predictions

validation_data = validation_data.sort_values(by=["month", "day_of_week", "hour"])

validation_data.to_csv("UHI_Predictions_Sorted.csv", index=False)
print("Predictions saved to 'UHI_Predictions_Sorted.csv'.")
# Out:
# Loading training data...
# Training data processed successfully.
# Loading validation data...
# /home/mids/m252994/yes/envs/gpu/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /home/mids/m252994/yes/envs/gpu/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-03-07 11:11:26.067998: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0330 - mae: 0.1456 - val_loss: 0.0341 - val_mae: 0.1542
# Epoch 2/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0331 - mae: 0.1456 - val_loss: 0.0342 - val_mae: 0.1546
# Epoch 3/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1453 - val_loss: 0.0334 - val_mae: 0.1525
# Epoch 4/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1450 - val_loss: 0.0334 - val_mae: 0.1525
# Epoch 5/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1454 - val_loss: 0.0334 - val_mae: 0.1525
# Epoch 6/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0329 - mae: 0.1455 - val_loss: 0.0333 - val_mae: 0.1522
# Epoch 7/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0335 - mae: 0.1468 - val_loss: 0.0333 - val_mae: 0.1522
# Epoch 8/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0324 - mae: 0.1444 - val_loss: 0.0320 - val_mae: 0.1489
# Epoch 9/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0328 - mae: 0.1450 - val_loss: 0.0335 - val_mae: 0.1528
# Epoch 10/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0331 - mae: 0.1466 - val_loss: 0.0332 - val_mae: 0.1520
# Epoch 11/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0335 - mae: 0.1470 - val_loss: 0.0337 - val_mae: 0.1534
# Epoch 12/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0318 - mae: 0.1434 - val_loss: 0.0340 - val_mae: 0.1541
# Epoch 13/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0323 - mae: 0.1446 - val_loss: 0.0324 - val_mae: 0.1500
# Epoch 14/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0330 - mae: 0.1462 - val_loss: 0.0333 - val_mae: 0.1523
# Epoch 15/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0328 - mae: 0.1455 - val_loss: 0.0328 - val_mae: 0.1508
# Epoch 16/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0329 - mae: 0.1456 - val_loss: 0.0334 - val_mae: 0.1525
# Epoch 17/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0334 - mae: 0.1468 - val_loss: 0.0331 - val_mae: 0.1517
# Epoch 18/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0330 - mae: 0.1456 - val_loss: 0.0342 - val_mae: 0.1545
# Epoch 19/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0330 - mae: 0.1457 - val_loss: 0.0347 - val_mae: 0.1558
# Epoch 20/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0323 - mae: 0.1442 - val_loss: 0.0334 - val_mae: 0.1525
# Epoch 21/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0321 - mae: 0.1437 - val_loss: 0.0340 - val_mae: 0.1540
# Epoch 22/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1451 - val_loss: 0.0330 - val_mae: 0.1516
# Epoch 23/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0327 - mae: 0.1448 - val_loss: 0.0326 - val_mae: 0.1504
# Epoch 24/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0323 - mae: 0.1447 - val_loss: 0.0326 - val_mae: 0.1504
# Epoch 25/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1448 - val_loss: 0.0343 - val_mae: 0.1547
# Epoch 26/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0327 - mae: 0.1456 - val_loss: 0.0325 - val_mae: 0.1503
# Epoch 27/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0325 - mae: 0.1446 - val_loss: 0.0335 - val_mae: 0.1526
# Epoch 28/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0334 - mae: 0.1463 - val_loss: 0.0340 - val_mae: 0.1539
# Epoch 29/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1452 - val_loss: 0.0332 - val_mae: 0.1520
# Epoch 30/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0325 - mae: 0.1446 - val_loss: 0.0332 - val_mae: 0.1519
# Epoch 31/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0330 - mae: 0.1458 - val_loss: 0.0333 - val_mae: 0.1523
# Epoch 32/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0331 - mae: 0.1468 - val_loss: 0.0326 - val_mae: 0.1504
# Epoch 33/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0333 - mae: 0.1465 - val_loss: 0.0339 - val_mae: 0.1537
# Epoch 34/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1458 - val_loss: 0.0333 - val_mae: 0.1522
# Epoch 35/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0328 - mae: 0.1454 - val_loss: 0.0337 - val_mae: 0.1532
# Epoch 36/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0318 - mae: 0.1431 - val_loss: 0.0330 - val_mae: 0.1515
# Epoch 37/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0331 - mae: 0.1466 - val_loss: 0.0337 - val_mae: 0.1534
# Epoch 38/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0334 - mae: 0.1473 - val_loss: 0.0332 - val_mae: 0.1519
# Epoch 39/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0334 - mae: 0.1471 - val_loss: 0.0341 - val_mae: 0.1542
# Epoch 40/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0324 - mae: 0.1449 - val_loss: 0.0326 - val_mae: 0.1503
# Epoch 41/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0323 - mae: 0.1448 - val_loss: 0.0331 - val_mae: 0.1518
# Epoch 42/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1456 - val_loss: 0.0332 - val_mae: 0.1520
# Epoch 43/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0321 - mae: 0.1433 - val_loss: 0.0336 - val_mae: 0.1529
# Epoch 44/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0325 - mae: 0.1454 - val_loss: 0.0332 - val_mae: 0.1519
# Epoch 45/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0327 - mae: 0.1451 - val_loss: 0.0333 - val_mae: 0.1522
# Epoch 46/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0333 - mae: 0.1464 - val_loss: 0.0333 - val_mae: 0.1523
# Epoch 47/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0336 - mae: 0.1473 - val_loss: 0.0333 - val_mae: 0.1522
# Epoch 48/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0329 - mae: 0.1459 - val_loss: 0.0338 - val_mae: 0.1535
# Epoch 49/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0330 - mae: 0.1459 - val_loss: 0.0334 - val_mae: 0.1524
# Epoch 50/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1451 - val_loss: 0.0328 - val_mae: 0.1509
# Epoch 51/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0324 - mae: 0.1451 - val_loss: 0.0333 - val_mae: 0.1521
# Epoch 52/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0322 - mae: 0.1437 - val_loss: 0.0333 - val_mae: 0.1523
# Epoch 53/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1448 - val_loss: 0.0330 - val_mae: 0.1513
# Epoch 54/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0328 - mae: 0.1458 - val_loss: 0.0333 - val_mae: 0.1523
# Epoch 55/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0329 - mae: 0.1455 - val_loss: 0.0334 - val_mae: 0.1526
# Epoch 56/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0329 - mae: 0.1449 - val_loss: 0.0332 - val_mae: 0.1519
# Epoch 57/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0331 - mae: 0.1460 - val_loss: 0.0331 - val_mae: 0.1518
# Epoch 58/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0329 - mae: 0.1460 - val_loss: 0.0333 - val_mae: 0.1522
# Epoch 59/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0328 - mae: 0.1452 - val_loss: 0.0334 - val_mae: 0.1526
# Epoch 60/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0327 - mae: 0.1451 - val_loss: 0.0329 - val_mae: 0.1513
# Epoch 61/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0327 - mae: 0.1457 - val_loss: 0.0331 - val_mae: 0.1517
# Epoch 62/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0323 - mae: 0.1439 - val_loss: 0.0330 - val_mae: 0.1515
# Epoch 63/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0325 - mae: 0.1449 - val_loss: 0.0327 - val_mae: 0.1507
# Epoch 64/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0327 - mae: 0.1449 - val_loss: 0.0329 - val_mae: 0.1513
# Epoch 65/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1450 - val_loss: 0.0329 - val_mae: 0.1513
# Epoch 66/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0325 - mae: 0.1454 - val_loss: 0.0334 - val_mae: 0.1526
# Epoch 67/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0319 - mae: 0.1436 - val_loss: 0.0332 - val_mae: 0.1519
# Epoch 68/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0327 - mae: 0.1456 - val_loss: 0.0335 - val_mae: 0.1528
# Epoch 69/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0332 - mae: 0.1470 - val_loss: 0.0339 - val_mae: 0.1538
# Epoch 70/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0325 - mae: 0.1443 - val_loss: 0.0331 - val_mae: 0.1516
# Epoch 71/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0325 - mae: 0.1443 - val_loss: 0.0330 - val_mae: 0.1515
# Epoch 72/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0325 - mae: 0.1443 - val_loss: 0.0334 - val_mae: 0.1525
# Epoch 73/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0330 - mae: 0.1459 - val_loss: 0.0332 - val_mae: 0.1520
# Epoch 74/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1454 - val_loss: 0.0331 - val_mae: 0.1516
# Epoch 75/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0328 - mae: 0.1455 - val_loss: 0.0333 - val_mae: 0.1522
# Epoch 76/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0324 - mae: 0.1441 - val_loss: 0.0329 - val_mae: 0.1512
# Epoch 77/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0328 - mae: 0.1455 - val_loss: 0.0334 - val_mae: 0.1524
# Epoch 78/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0330 - mae: 0.1455 - val_loss: 0.0334 - val_mae: 0.1525
# Epoch 79/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0330 - mae: 0.1455 - val_loss: 0.0329 - val_mae: 0.1511
# Epoch 80/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0327 - mae: 0.1454 - val_loss: 0.0338 - val_mae: 0.1535
# Epoch 81/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0323 - mae: 0.1442 - val_loss: 0.0332 - val_mae: 0.1519
# Epoch 82/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1445 - val_loss: 0.0334 - val_mae: 0.1525
# Epoch 83/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0327 - mae: 0.1450 - val_loss: 0.0331 - val_mae: 0.1517
# Epoch 84/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1451 - val_loss: 0.0335 - val_mae: 0.1528
# Epoch 85/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0327 - mae: 0.1450 - val_loss: 0.0333 - val_mae: 0.1523
# Epoch 86/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0322 - mae: 0.1441 - val_loss: 0.0330 - val_mae: 0.1513
# Epoch 87/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0328 - mae: 0.1453 - val_loss: 0.0333 - val_mae: 0.1522
# Epoch 88/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0335 - mae: 0.1468 - val_loss: 0.0335 - val_mae: 0.1528
# Epoch 89/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0324 - mae: 0.1447 - val_loss: 0.0330 - val_mae: 0.1514
# Epoch 90/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0332 - mae: 0.1461 - val_loss: 0.0335 - val_mae: 0.1528
# Epoch 91/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0330 - mae: 0.1455 - val_loss: 0.0334 - val_mae: 0.1526
# Epoch 92/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0322 - mae: 0.1446 - val_loss: 0.0333 - val_mae: 0.1521
# Epoch 93/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0324 - mae: 0.1443 - val_loss: 0.0336 - val_mae: 0.1530
# Epoch 94/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0329 - mae: 0.1461 - val_loss: 0.0334 - val_mae: 0.1526
# Epoch 95/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0325 - mae: 0.1453 - val_loss: 0.0334 - val_mae: 0.1525
# Epoch 96/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0328 - mae: 0.1453 - val_loss: 0.0334 - val_mae: 0.1525
# Epoch 97/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0334 - mae: 0.1470 - val_loss: 0.0331 - val_mae: 0.1518
# Epoch 98/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0315 - mae: 0.1420 - val_loss: 0.0333 - val_mae: 0.1521
# Epoch 99/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0326 - mae: 0.1455 - val_loss: 0.0333 - val_mae: 0.1522
# Epoch 100/100
# 281/281 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0332 - mae: 0.1463 - val_loss: 0.0332 - val_mae: 0.1520
# Model training complete.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# ### Model Evaluation on Training Data ###
# Mean Absolute Error (MAE): 0.1466
# Mean Squared Error (MSE): 0.0328
# Root Mean Squared Error (RMSE): 0.1812
# R² Score: -0.0069
# Making predictions on validation dataset...
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Predictions saved to 'UHI_Predictions_Sorted.csv'.
